# %%
# !pip install -q earthengine-api geemap prophet fastapi uvicorn geopandas rasterio
print
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 88.3 MB/s eta 0:00:00
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
import ee
import geemap

# Nota: El usuario debe ejecutar ee.Authenticate() la primera vez para enlazar su cuenta de Google Earth Engine
print("Preparando módulos de Google Earth Engine para el análisis histórico (2014-2024)...")
print("Listo para la descarga de datos de focos de calor (NASA FIRMS).")
# Out:
# Preparando módulos de Google Earth Engine para el análisis histórico (2014-2024)...
# Listo para la descarga de datos de focos de calor (NASA FIRMS).
